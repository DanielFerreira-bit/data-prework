# %%
gandalf = [10, 11, 13, 30, 22, 11, 10, 33, 22, 22]
standard_deviation_G = 17,79513042
saruman = [23, 66, 12, 43, 12, 10, 44, 23, 12, 17]
standard_deviation_S = 16,4062996

if (gandalf[0] > saruman[0]):
    print("Gandalf wins")
elif (gandalf[0] < saruman[0]):
    print("Saruman wins")
if (gandalf[1] > saruman[1]):
    print("Gandalf wins")
elif (gandalf[1] < saruman[1]):
    print("Saruman wins")
if (gandalf[2] > saruman[2]):
    print("Gandalf wins")
elif (gandalf[2] < saruman[2]):
    print("Saruman wins")
if (gandalf[3] > saruman[3]):
    print("Gandalf wins")
elif (gandalf[3] < saruman[3]):
    print("Saruman wins")
if (gandalf[4] > saruman[4]):
    print("Gandalf wins")
elif (gandalf[4] < saruman[4]):
    print("Saruman wins")
if (gandalf[5] > saruman[5]):
    print("Gandalf wins")
elif (gandalf[5] < saruman[5]):
    print("Saruman wins")
if (gandalf[6] > saruman[6]):
    print("Gandalf wins")
elif (gandalf[6] < saruman[6]):
    print("Saruman wins")
if (gandalf[7] > saruman[7]):
    print("Gandalf wins")
elif (gandalf[7] < saruman[7]):
    print("Saruman wins")
if (gandalf[8] > saruman[8]):
    print("Gandalf wins")
elif (gandalf[8] < saruman[8]):
    print("Saruman wins")
if (gandalf[9] > saruman[9]):
    print("Gandalf wins")
elif (gandalf[9] < saruman[9]):
    print("Saruman wins")
    
list(gandalf)
# Addition
Average_power_G = sum(gandalf)/len(gandalf)
list(saruman)
# Addition
Average_power_S = sum(saruman)/len(saruman)

    
POWER = {
    'Fireball': 50, 
    'Lightning bolt': 40, 
    'Magic arrow': 10, 
    'Black Tentacles': 25, 
    'Contagion': 45
}
gandalf = ['Fireball', 'Lightning bolt', 'Lightning bolt', 'Magic arrow', 'Fireball', 
           'Magic arrow', 'Lightning bolt', 'Fireball', 'Fireball', 'Fireball']
saruman = ['Contagion', 'Contagion', 'Black Tentacles', 'Fireball', 'Black Tentacles', 
           'Lightning bolt', 'Magic arrow', 'Contagion', 'Magic arrow', 'Magic arrow']

if (gandalf[0] > saruman[0]):
    if (gandalf[1] > saruman[1]) & (gandalf[2] > saruman[2]):
        print("Gandalf wins")
        

print(Average_power_G)
print(Average_power_S)
print(standard_deviation_G)
print(standard_deviation_S)
# Out:
# Saruman wins
# Saruman wins
# Gandalf wins
# Saruman wins
# Gandalf wins
# Gandalf wins
# Saruman wins
# Gandalf wins
# Gandalf wins
# Gandalf wins
# Gandalf wins
# 18.4
# 26.2
# (17, 79513042)
# (16, 4062996)
